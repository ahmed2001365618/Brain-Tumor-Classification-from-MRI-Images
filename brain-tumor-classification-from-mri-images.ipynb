# %% [markdown]
#  # Brain Tumor Classification from MRI Images
#
# ## Introduction
#
# Brain tumor classification is a critical task in the field of medical imaging and healthcare. Magnetic Resonance Imaging (MRI) is a widely used non-invasive technique to visualize the brain's internal structures and identify abnormalities, such as tumors. Early and accurate detection of brain tumors plays a crucial role in enabling timely medical intervention and improving patient outcomes.
#
# In this Kaggle notebook, we will develop a machine learning model to classify brain MRI images into four categories: 'notumor', 'glioma', 'meningioma', and 'pituitary' tumors. The model will be trained on a labeled dataset containing brain MRI images of patients with and without tumors.
#
# ## Dataset
#
# The dataset used for this project consists of brain MRI images collected from various sources. Each MRI image is labeled with the corresponding tumor type: 'notumor', 'glioma', 'meningioma', or 'pituitary'. The dataset is divided into two parts: the training set and the test set.
#
# *   Training Set: This set contains a large number of labeled brain MRI images, which will be used to train the machine learning model.
# *   Test Set: The test set comprises a separate collection of labeled brain MRI images that will be used to evaluate the model's performance and generalization ability.
#
# ## Goals
#
# The primary objective of this project is to build a robust machine learning model capable of accurately classifying brain MRI images into the appropriate tumor category. Specifically, we aim to achieve the following:
#
# 1.  Data Preprocessing: Perform necessary data preprocessing steps to prepare the brain MRI images for training the model.
# 2.  Model Development: Implement and train a deep learning model using convolutional neural networks (CNNs) to classify brain tumors.
# 3.  Model Evaluation: Evaluate the trained model on the test set to measure its performance in terms of accuracy, precision, recall, and F1 score.
# 4.  Model Interpretation: Explore methods for interpreting the model's predictions to gain insights into its decision-making process.
#
# ## Methodology
#
# The following steps will be followed to accomplish our goals:
#
# 1.  Data Loading and Exploration: Load the brain MRI dataset, visualize sample images, and gain a better understanding of the data distribution.
# 2.  Data Preprocessing: Prepare the data for training by performing image resizing, normalization, and augmentation techniques.
# 3.  Model Architecture: Design a CNN architecture suitable for brain tumor classification and implement it using a deep learning framework.
# 4.  Model Training: Train the CNN model on the preprocessed training data and monitor its performance on validation data.
# 5.  Model Evaluation: Evaluate the trained model on the test set to assess its performance and generalization capabilities.
# 6.  Interpretation and Visualization: Explore techniques to interpret the model's predictions and visualize its learned features.
#
# ## Conclusion
#
# By the end of this notebook, we aim to have a well-trained machine learning model capable of accurately classifying brain MRI images into 'notumor', 'glioma', 'meningioma', or 'pituitary' tumor categories. The successful development of such a model can significantly contribute to the early detection and treatment of brain tumors, leading to improved patient care and outcomes in the field of neurology and neurosurgery.
#
# Let's get started with loading and exploring the data!

# %% [markdown]
# ## Brain Tumor Classification from MRI Images - Data Preparation
#
# In this section of the notebook, we will prepare the data for training a machine learning model to classify brain MRI images into four tumor categories: 'notumor', 'glioma', 'meningioma', and 'pituitary'. We will use TensorFlow and other essential libraries for data handling and visualization.
#
# ### Libraries and Parameters
#
# We begin by importing the necessary libraries for our project:

# %%
import os
import PIL
import pathlib
import numpy as np
import pandas as pd
import tensorflow as tf
import matplotlib.pyplot as plt

import warnings
warnings.filterwarnings('ignore')

TRAINING_DATA_DIR = '/kaggle/input/brain-tumor-mri-dataset/Training/'
TEST_DATA_DIR = '/kaggle/input/brain-tumor-mri-dataset/Testing/'
BATCH_SIZE = 32
IMG_HEIGHT = 224
IMG_WIDTH = 224
EPOCHS=200
# Out:
# /opt/conda/lib/python3.10/site-packages/scipy/__init__.py:146: UserWarning: A NumPy version >=1.16.5 and <1.23.0 is required for this version of SciPy (detected version 1.23.5
#   warnings.warn(f"A NumPy version >={np_minversion} and <{np_maxversion}"
# /opt/conda/lib/python3.10/site-packages/tensorflow_io/python/ops/__init__.py:98: UserWarning: unable to load libtensorflow_io_plugins.so: unable to open file: libtensorflow_io_plugins.so, from paths: ['/opt/conda/lib/python3.10/site-packages/tensorflow_io/python/ops/libtensorflow_io_plugins.so']
# caused by: ['/opt/conda/lib/python3.10/site-packages/tensorflow_io/python/ops/libtensorflow_io_plugins.so: undefined symbol: _ZN3tsl6StatusC1EN10tensorflow5error4CodeESt17basic_string_viewIcSt11char_traitsIcEENS_14SourceLocationE']
#   warnings.warn(f"unable to load libtensorflow_io_plugins.so: {e}")
# /opt/conda/lib/python3.10/site-packages/tensorflow_io/python/ops/__init__.py:104: UserWarning: file system plugins are not loaded: unable to open file: libtensorflow_io.so, from paths: ['/opt/conda/lib/python3.10/site-packages/tensorflow_io/python/ops/libtensorflow_io.so']
# caused by: ['/opt/conda/lib/python3.10/site-packages/tensorflow_io/python/ops/libtensorflow_io.so: undefined symbol: _ZTVN10tensorflow13GcsFileSystemE']
#   warnings.warn(f"file system plugins are not loaded: {e}")

# %% [markdown]
# ### Data Loading and Exploration
#
# We use pathlib to create Path objects for the training and test data directories:

# %%
data_dir = pathlib.Path(TRAINING_DATA_DIR).with_suffix('')
test_data_dir = pathlib.Path(TEST_DATA_DIR).with_suffix('')
image_count = len(list(data_dir.glob('*/*.jpg')))
print(f'There are {image_count} images in training dataset.')
# Out:
# There are 5712 images in training dataset.

# %% [markdown]
# ### Dataset Directory Listing
#
# We can also list the subdirectories present in the training data directory, each representing one of the tumor categories:

# %%
list(data_dir.glob('*'))
# Out:
# [PosixPath('/kaggle/input/brain-tumor-mri-dataset/Training/pituitary'),
#  PosixPath('/kaggle/input/brain-tumor-mri-dataset/Training/notumor'),
#  PosixPath('/kaggle/input/brain-tumor-mri-dataset/Training/meningioma'),
#  PosixPath('/kaggle/input/brain-tumor-mri-dataset/Training/glioma')]

# %% [markdown]
# ## Data Exploration - Sample Images
#
# Let's explore the brain MRI images from the 'pituitary' and 'meningioma' subdirectories of the training dataset. We will visualize a few sample images from each category to get a better understanding of the data.
#
# ### Sample Images from 'pituitary' Tumor Category
#
# We begin by loading and displaying two sample images from the 'pituitary' tumor category:

# %%
pituitary = list(data_dir.glob('pituitary/*'))
PIL.Image.open(str(pituitary[0]))
# Out:
# <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=512x512>

# %%
def shape_of_mr_image(category, index):
    image_path = str(category[index])
    image = tf.io.read_file(image_path)
    image = tf.image.decode_jpeg(image, channels=3)
    shape = tf.shape(image)
    print(f"Shape of the image: {shape}")

shape_of_mr_image(pituitary, 0)
# Out:
# Shape of the image: [512 512   3]

# %%
PIL.Image.open(str(pituitary[1]))
# Out:
# <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=512x512>

# %%
shape_of_mr_image(pituitary, 1)
# Out:
# Shape of the image: [512 512   3]

# %% [markdown]
# ### Sample Images from 'meningioma' Tumor Category
#
# Next, let's load and visualize two sample images from the 'meningioma' tumor category:

# %%
meningioma = list(data_dir.glob('meningioma/*'))
PIL.Image.open(str(meningioma[0]))
# Out:
# <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=512x512>

# %%
shape_of_mr_image(meningioma, 0)
# Out:
# Shape of the image: [512 512   3]

# %%
PIL.Image.open(str(meningioma[1]))
# Out:
# <PIL.JpegImagePlugin.JpegImageFile image mode=L size=512x512>

# %%
shape_of_mr_image(meningioma, 1)
# Out:
# Shape of the image: [512 512   3]

# %% [markdown]
# ## Data Preparation - TensorFlow Data Pipelines
#
# To train our brain tumor classification model, we need to create data pipelines that load and preprocess the images from the appropriate directories. TensorFlow provides a convenient function called `tf.keras.utils.image_dataset_from_directory` to achieve this. We will use this function to load the images, split them into training and validation sets, and perform necessary preprocessing.
#
# ### Training Dataset
#
# We start by loading the training dataset:

# %%
train_ds = tf.keras.utils.image_dataset_from_directory(
  data_dir,
  validation_split=0.2,
  subset="training",
  seed=123,
  image_size=(IMG_HEIGHT, IMG_WIDTH),
  batch_size=BATCH_SIZE)
# Out:
# Found 5712 files belonging to 4 classes.
# Using 4570 files for training.

# %% [markdown]
# The function successfully finds and loads 5712 image files from the 'notumor', 'glioma', 'meningioma', and 'pituitary' subdirectories. From these, 4570 files are used for training.
#
# ### Validation Dataset
#
# Next, we create the validation dataset:

# %%
val_ds = tf.keras.utils.image_dataset_from_directory(
  data_dir,
  validation_split=0.2,
  subset="validation",
  seed=123,
  image_size=(IMG_HEIGHT, IMG_WIDTH),
  batch_size=BATCH_SIZE)
# Out:
# Found 5712 files belonging to 4 classes.
# Using 1142 files for validation.

# %% [markdown]
# The function finds the same 5712 image files and selects 1142 of them for validation. The validation_split=0.2 argument ensures that 20% of the data is set aside for validation.
#
# ### Class Names
#
# We also extract the class names from the training dataset:

# %%
class_names = train_ds.class_names
print(class_names)
# Out:
# ['glioma', 'meningioma', 'notumor', 'pituitary']

# %% [markdown]
# The class_names list contains the unique tumor categories in our dataset, which are 'glioma', 'meningioma', 'notumor', and 'pituitary'.

# %% [markdown]
# The output shows the count of images for each tumor category: 'pituitary', 'meningioma', 'glioma', and 'notumor'.
#
# ### Class Weights Calculation
#
# Next, we calculate the class weights using the sklearn.utils.class_weight:

# %%
from sklearn.utils.class_weight import compute_class_weight

class_labels = np.array([label for images, labels in train_ds for label in labels.numpy()])
class_counts = np.unique(class_labels, return_counts=True)[1]

# Calculate class weights using balanced inverse frequency (corrected call)
class_weights = compute_class_weight("balanced", classes=np.unique(class_labels), y=class_labels)

for class_name, weight in zip(class_names, class_weights):
    print(f"Class '{class_name}': Weight {weight:.4f}")
# Out:
# Class 'glioma': Weight 1.0482
# Class 'meningioma': Weight 1.0964
# Class 'notumor': Weight 0.8968
# Class 'pituitary': Weight 0.9815

# %%
class_weights = {0:class_weights[0], 1:class_weights[1], 2:class_weights[2], 3:class_weights[3],}
class_weights
# Out:
# {0: 1.048165137614679,
#  1: 1.0964491362763915,
#  2: 0.8967817896389325,
#  3: 0.9815292096219931}

# %% [markdown]
# Class weights are used during model training to adjust the loss function, giving more emphasis to examples from underrepresented classes.
# This helps the model learn to classify those classes more accurately, even when they have fewer training examples.
# By incorporating class weights, we aim to create a more robust model that can effectively detect different tumor types, regardless of their prevalence in the dataset.

# %% [markdown]
# ## Data Visualization - Sample Images
#
# In this section, we visualize a few sample images from the training dataset to gain insights into the brain MRI data that will be used for training our brain tumor classification model.
#
# ### Sample Images with Class Labels
#
# We use matplotlib to display a 3x3 grid of sample images from the training dataset, along with their respective class labels:

# %%
plt.figure(figsize=(10, 10))
for images, labels in train_ds.take(1):
  for i in range(9):
    ax = plt.subplot(3, 3, i + 1)
    plt.imshow(images[i].numpy().astype("uint8"))
    plt.title(class_names[labels[i]])
    plt.axis("off")

# %%
for image_batch, labels_batch in train_ds:
  print(image_batch.shape)
  print(labels_batch.shape)
  break
# Out:
# (32, 224, 224, 3)
# (32,)

# %% [markdown]
# *   `[Dataset.cache](https://www.tensorflow.org/api_docs/python/tf/data/Dataset#cache)` keeps the images in memory after they're loaded off disk during the first epoch. This will ensure the dataset does not become a bottleneck while training your model. If your dataset is too large to fit into memory, you can also use this method to create a performant on-disk cache.
# *   `[Dataset.prefetch](https://www.tensorflow.org/api_docs/python/tf/data/Dataset#prefetch)` overlaps data preprocessing and model execution while training.

# %%
AUTOTUNE = tf.data.AUTOTUNE

train_ds = train_ds.cache().shuffle(1000).prefetch(buffer_size=AUTOTUNE)
val_ds = val_ds.cache().prefetch(buffer_size=AUTOTUNE)

# %% [markdown]
# ## Data Augmentation for Training
#
# To enhance the diversity of the training dataset and improve the model's generalization, we apply data augmentation techniques to the images. We use `tf.keras.Sequential` to create a sequence of augmentation layers and then visualize the augmented images.
#
# ### Data Augmentation Techniques
#
# We define the data augmentation sequence as follows:

# %%
data_augmentation = tf.keras.Sequential([
    tf.keras.layers.RandomFlip("horizontal", input_shape=(IMG_HEIGHT, IMG_WIDTH, 3)),
    tf.keras.layers.RandomRotation(0.05),
    tf.keras.layers.RandomZoom(0.05)
])

plt.figure(figsize=(10, 10))
for images, _ in train_ds.take(1):
  for i in range(9):
    augmented_images = data_augmentation(images)
    ax = plt.subplot(3, 3, i + 1)
    plt.imshow(augmented_images[0].numpy().astype("uint8"))
    plt.axis("off")

# %% [markdown]
# The code above displays a 3x3 grid of augmented images generated from a single batch of training data. Each time you run this code block, you will see different augmentations applied to the same set of images.

# %% [markdown]
# ## Brain Tumor Classification Model
#
# In this section, we define the CNN model for brain tumor classification using TensorFlow. The model consists of several layers, including data augmentation, convolutional layers, batch normalization, dropout, and dense layers.
#
# ### Model Architecture

# %%
model = tf.keras.Sequential([
    data_augmentation,
    tf.keras.layers.BatchNormalization(),
    tf.keras.layers.Conv2D(32, (3,3), activation='relu'),
    tf.keras.layers.MaxPooling2D(2,2),
    tf.keras.layers.BatchNormalization(),
    tf.keras.layers.Dropout(0.20),
    tf.keras.layers.Conv2D(64, (3,3), activation='relu'),
    tf.keras.layers.MaxPooling2D(2,2),
    tf.keras.layers.BatchNormalization(),
    tf.keras.layers.Dropout(0.20),
    tf.keras.layers.Conv2D(128, (5,5), activation='relu'),
    tf.keras.layers.MaxPooling2D(2,2),
    tf.keras.layers.BatchNormalization(),
    tf.keras.layers.Dropout(0.25),
    tf.keras.layers.Flatten(),
    tf.keras.layers.Dense(256, activation='relu', kernel_regularizer=tf.keras.regularizers.l2(l=0.015)),
    tf.keras.layers.BatchNormalization(),
    tf.keras.layers.Dropout(0.25),
    tf.keras.layers.Dense(128, activation='relu', kernel_regularizer=tf.keras.regularizers.l2(l=0.015)),
    tf.keras.layers.BatchNormalization(),
    tf.keras.layers.Dropout(0.25),
    tf.keras.layers.Dense(64, activation='relu', kernel_regularizer=tf.keras.regularizers.l2(l=0.015)),
    tf.keras.layers.BatchNormalization(),
    tf.keras.layers.Dense(4, activation='softmax')
])

# Define custom precision and recall metrics
def precision(y_true, y_pred):
    true_positives = tf.keras.backend.sum(tf.keras.backend.round(tf.keras.backend.clip(y_true * y_pred, 0, 1)))
    predicted_positives = tf.keras.backend.sum(tf.keras.backend.round(tf.keras.backend.clip(y_pred, 0, 1)))
    return true_positives / (predicted_positives + tf.keras.backend.epsilon())

def recall(y_true, y_pred):
    true_positives = tf.keras.backend.sum(tf.keras.backend.round(tf.keras.backend.clip(y_true * y_pred, 0, 1)))
    possible_positives = tf.keras.backend.sum(tf.keras.backend.round(tf.keras.backend.clip(y_true, 0, 1)))
    return true_positives / (possible_positives + tf.keras.backend.epsilon())

model.compile(optimizer=tf.keras.optimizers.Adam(),
              loss=tf.keras.losses.SparseCategoricalCrossentropy(),
              metrics=[tf.keras.metrics.SparseCategoricalAccuracy(), precision, recall])

# Two callbacks are defined: EarlyStopping to stop training early if the validation loss does not improve after a certain number of epochs
# and ReduceLROnPlateau to reduce the learning rate when the validation loss plateaus.
              
early_stopping = tf.keras.callbacks.EarlyStopping(monitor='val_loss', min_delta=0.001, patience=10, restore_best_weights=True)
lr_sch = tf.keras.callbacks.ReduceLROnPlateau(monitor = 'val_loss', patience= 5, factor = 0.1, verbose = 1, min_lr = 5e-10)

model.summary()
# Out:
# Model: "sequential_1"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  sequential (Sequential)     (None, 224, 224, 3)       0
#
#  batch_normalization (BatchN  (None, 224, 224, 3)      12
#  ormalization)
#
#  conv2d (Conv2D)             (None, 222, 222, 32)      896
#
#  max_pooling2d (MaxPooling2D  (None, 111, 111, 32)     0
#  )
#
#  batch_normalization_1 (Batc  (None, 111, 111, 32)     128
#  hNormalization)
#
#  dropout (Dropout)           (None, 111, 111, 32)      0
#
#  conv2d_1 (Conv2D)           (None, 109, 109, 64)      18496
#
#  max_pooling2d_1 (MaxPooling  (None, 54, 54, 64)       0
#  2D)
#
#  batch_normalization_2 (Batc  (None, 54, 54, 64)       256
#  hNormalization)
#
#  dropout_1 (Dropout)         (None, 54, 54, 64)        0
#
#  conv2d_2 (Conv2D)           (None, 50, 50, 128)       204928
#
#  max_pooling2d_2 (MaxPooling  (None, 25, 25, 128)      0
#  2D)
#
#  batch_normalization_3 (Batc  (None, 25, 25, 128)      512
#  hNormalization)
#
#  dropout_2 (Dropout)         (None, 25, 25, 128)       0
#
#  flatten (Flatten)           (None, 80000)             0
#
#  dense (Dense)               (None, 256)               20480256
#
#  batch_normalization_4 (Batc  (None, 256)              1024
#  hNormalization)
#
#  dropout_3 (Dropout)         (None, 256)               0
#
#  dense_1 (Dense)             (None, 128)               32896
#
#  batch_normalization_5 (Batc  (None, 128)              512
#  hNormalization)
#
#  dropout_4 (Dropout)         (None, 128)               0
#
#  dense_2 (Dense)             (None, 64)                8256
#
#  batch_normalization_6 (Batc  (None, 64)               256
#  hNormalization)
#
#  dense_3 (Dense)             (None, 4)                 260
#
# =================================================================
# Total params: 20,748,688
# Trainable params: 20,747,338
# Non-trainable params: 1,350
# _________________________________________________________________

# %% [markdown]
# ## Model Training and Metrics Visualization
#
# In this section, we train the brain tumor classification model and visualize the training progress, including accuracy, loss, precision, and recall, over the epochs.
#
# ### Model Training
#
# We start model training by using the `model.fit` method. The model is trained on the training dataset (`train_ds`) and validated on the validation dataset (`val_ds`). We specify the number of epochs (`EPOCHS`) and also provide custom class weights to handle class imbalance in the data.

# %%
history = model.fit(train_ds,
                    validation_data=val_ds,
                    epochs=EPOCHS,
                    class_weight=class_weights,
                    callbacks=[early_stopping, lr_sch])
# Out:
# Epoch 1/200
# 2024-01-11 11:28:44.014030: E tensorflow/core/grappler/optimizers/meta_optimizer.cc:954] layout failed: INVALID_ARGUMENT: Size of values 0 does not match size of permutation 4 @ fanin shape insequential_1/dropout/dropout/SelectV2-2-TransposeNHWCToNCHW-LayoutOptimizer
# 143/143 [==============================] - 33s 141ms/step - loss: 10.1179 - sparse_categorical_accuracy: 0.7168 - precision: 1.0275 - recall: 1.1871 - val_loss: 5.6299 - val_sparse_categorical_accuracy: 0.5989 - val_precision: 1.6292 - val_recall: 1.2701 - lr: 0.0010
# Epoch 2/200
# 143/143 [==============================] - 16s 114ms/step - loss: 4.1032 - sparse_categorical_accuracy: 0.7735 - precision: 0.9591 - recall: 1.1457 - val_loss: 4.3635 - val_sparse_categorical_accuracy: 0.5035 - val_precision: 0.9587 - val_recall: 1.0185 - lr: 0.0010
# Epoch 3/200
# 143/143 [==============================] - 16s 114ms/step - loss: 3.1450 - sparse_categorical_accuracy: 0.7792 - precision: 0.9481 - recall: 1.1402 - val_loss: 2.9691 - val_sparse_categorical_accuracy: 0.7102 - val_precision: 0.9667 - val_recall: 1.0823 - lr: 0.0010
# Epoch 4/200
# 143/143 [==============================] - 16s 114ms/step - loss: 2.5697 - sparse_categorical_accuracy: 0.7849 - precision: 0.9456 - recall: 1.1387 - val_loss: 2.2003 - val_sparse_categorical_accuracy: 0.8310 - val_precision: 0.9175 - val_recall: 1.0532 - lr: 0.0010
# Epoch 5/200
# 143/143 [==============================] - 16s 113ms/step - loss: 2.4123 - sparse_categorical_accuracy: 0.7930 - precision: 0.9229 - recall: 1.1227 - val_loss: 2.4801 - val_sparse_categorical_accuracy: 0.6961 - val_precision: 1.0163 - val_recall: 1.0341 - lr: 0.0010
# Epoch 6/200
# 143/143 [==============================] - 16s 113ms/step - loss: 2.2836 - sparse_categorical_accuracy: 0.7991 - precision: 0.9342 - recall: 1.1392 - val_loss: 2.2492 - val_sparse_categorical_accuracy: 0.7968 - val_precision: 0.9189 - val_recall: 1.0719 - lr: 0.0010
# Epoch 7/200
# 143/143 [==============================] - 16s 114ms/step - loss: 2.0520 - sparse_categorical_accuracy: 0.8020 - precision: 0.9402 - recall: 1.1538 - val_loss: 1.9255 - val_sparse_categorical_accuracy: 0.8371 - val_precision: 0.9007 - val_recall: 1.0741 - lr: 0.0010
# Epoch 8/200
# 143/143 [==============================] - 16s 113ms/step - loss: 2.1975 - sparse_categorical_accuracy: 0.7991 - precision: 0.9311 - recall: 1.1496 - val_loss: 2.0413 - val_sparse_categorical_accuracy: 0.7820 - val_precision: 0.9895 - val_recall: 1.1549 - lr: 0.0010
# Epoch 9/200
# 143/143 [==============================] - 16s 113ms/step - loss: 2.1060 - sparse_categorical_accuracy: 0.8175 - precision: 0.9076 - recall: 1.1349 - val_loss: 4.3202 - val_sparse_categorical_accuracy: 0.5158 - val_precision: 0.8794 - val_recall: 1.0776 - lr: 0.0010
# Epoch 10/200
# 143/143 [==============================] - 16s 114ms/step - loss: 2.2184 - sparse_categorical_accuracy: 0.8133 - precision: 0.9211 - recall: 1.1359 - val_loss: 2.4881 - val_sparse_categorical_accuracy: 0.6856 - val_precision: 0.8561 - val_recall: 1.0022 - lr: 0.0010
# Epoch 11/200
# 143/143 [==============================] - 16s 114ms/step - loss: 2.1890 - sparse_categorical_accuracy: 0.8217 - precision: 0.9056 - recall: 1.1203 - val_loss: 2.0794 - val_sparse_categorical_accuracy: 0.7566 - val_precision: 1.0663 - val_recall: 1.1946 - lr: 0.0010
# Epoch 12/200
# 143/143 [==============================] - ETA: 0s - loss: 2.2790 - sparse_categorical_accuracy: 0.8239 - precision: 0.8876 - recall: 1.1134
# Epoch 12: ReduceLROnPlateau reducing learning rate to 0.00010000000474974513.
# 143/143 [==============================] - 16s 115ms/step - loss: 2.2790 - sparse_categorical_accuracy: 0.8239 - precision: 0.8876 - recall: 1.1134 - val_loss: 2.2621 - val_sparse_categorical_accuracy: 0.6909 - val_precision: 1.0244 - val_recall: 1.2111 - lr: 0.0010
# Epoch 13/200
# 143/143 [==============================] - 17s 116ms/step - loss: 1.4082 - sparse_categorical_accuracy: 0.8796 - precision: 0.8509 - recall: 1.0831 - val_loss: 1.0602 - val_sparse_categorical_accuracy: 0.8853 - val_precision: 0.8274 - val_recall: 0.9967 - lr: 1.0000e-04
# Epoch 14/200
# 143/143 [==============================] - 17s 116ms/step - loss: 0.8670 - sparse_categorical_accuracy: 0.9053 - precision: 0.8336 - recall: 1.0755 - val_loss: 0.8375 - val_sparse_categorical_accuracy: 0.9107 - val_precision: 0.8446 - val_recall: 1.0045 - lr: 1.0000e-04
# Epoch 15/200
# 143/143 [==============================] - 16s 115ms/step - loss: 0.7682 - sparse_categorical_accuracy: 0.9136 - precision: 0.8186 - recall: 1.0583 - val_loss: 0.8443 - val_sparse_categorical_accuracy: 0.8923 - val_precision: 0.8159 - val_recall: 0.9975 - lr: 1.0000e-04
# Epoch 16/200
# 143/143 [==============================] - 17s 116ms/step - loss: 0.7403 - sparse_categorical_accuracy: 0.9206 - precision: 0.8150 - recall: 1.0552 - val_loss: 0.8205 - val_sparse_categorical_accuracy: 0.8827 - val_precision: 0.8032 - val_recall: 0.9750 - lr: 1.0000e-04
# Epoch 17/200
# 143/143 [==============================] - 16s 115ms/step - loss: 0.7386 - sparse_categorical_accuracy: 0.9309 - precision: 0.8104 - recall: 1.0488 - val_loss: 1.0056 - val_sparse_categorical_accuracy: 0.8030 - val_precision: 0.8060 - val_recall: 0.9796 - lr: 1.0000e-04
# Epoch 18/200
# 143/143 [==============================] - 17s 116ms/step - loss: 0.7221 - sparse_categorical_accuracy: 0.9304 - precision: 0.8045 - recall: 1.0440 - val_loss: 0.7783 - val_sparse_categorical_accuracy: 0.9194 - val_precision: 0.8092 - val_recall: 1.0039 - lr: 1.0000e-04
# Epoch 19/200
# 143/143 [==============================] - 16s 115ms/step - loss: 0.7311 - sparse_categorical_accuracy: 0.9348 - precision: 0.8067 - recall: 1.0466 - val_loss: 0.9435 - val_sparse_categorical_accuracy: 0.8503 - val_precision: 0.8100 - val_recall: 0.9844 - lr: 1.0000e-04
# Epoch 20/200
# 143/143 [==============================] - 17s 116ms/step - loss: 0.7379 - sparse_categorical_accuracy: 0.9389 - precision: 0.8004 - recall: 1.0407 - val_loss: 0.7335 - val_sparse_categorical_accuracy: 0.9361 - val_precision: 0.8095 - val_recall: 0.9991 - lr: 1.0000e-04
# Epoch 21/200
# 143/143 [==============================] - 16s 115ms/step - loss: 0.7171 - sparse_categorical_accuracy: 0.9438 - precision: 0.7920 - recall: 1.0333 - val_loss: 0.8818 - val_sparse_categorical_accuracy: 0.8774 - val_precision: 0.8036 - val_recall: 0.9951 - lr: 1.0000e-04
# Epoch 22/200
# 143/143 [==============================] - 16s 115ms/step - loss: 0.7320 - sparse_categorical_accuracy: 0.9405 - precision: 0.7926 - recall: 1.0325 - val_loss: 0.9396 - val_sparse_categorical_accuracy: 0.8345 - val_precision: 0.8049 - val_recall: 0.9903 - lr: 1.0000e-04
# Epoch 23/200
# 143/143 [==============================] - 16s 115ms/step - loss: 0.6970 - sparse_categorical_accuracy: 0.9532 - precision: 0.7898 - recall: 1.0317 - val_loss: 0.7828 - val_sparse_categorical_accuracy: 0.9238 - val_precision: 0.8166 - val_recall: 1.0155 - lr: 1.0000e-04
# Epoch 24/200
# 143/143 [==============================] - 17s 116ms/step - loss: 0.6604 - sparse_categorical_accuracy: 0.9593 - precision: 0.7829 - recall: 1.0241 - val_loss: 0.6763 - val_sparse_categorical_accuracy: 0.9475 - val_precision: 0.8051 - val_recall: 1.0027 - lr: 1.0000e-04
# Epoch 25/200
# 143/143 [==============================] - 16s 115ms/step - loss: 0.6928 - sparse_categorical_accuracy: 0.9538 - precision: 0.7878 - recall: 1.0292 - val_loss: 0.8549 - val_sparse_categorical_accuracy: 0.9046 - val_precision: 0.8052 - val_recall: 1.0067 - lr: 1.0000e-04
# Epoch 26/200
# 143/143 [==============================] - 16s 115ms/step - loss: 0.6815 - sparse_categorical_accuracy: 0.9582 - precision: 0.7857 - recall: 1.0273 - val_loss: 0.7766 - val_sparse_categorical_accuracy: 0.9221 - val_precision: 0.8150 - val_recall: 1.0133 - lr: 1.0000e-04
# Epoch 27/200
# 143/143 [==============================] - 16s 115ms/step - loss: 0.6527 - sparse_categorical_accuracy: 0.9591 - precision: 0.7904 - recall: 1.0314 - val_loss: 0.7829 - val_sparse_categorical_accuracy: 0.9046 - val_precision: 0.8043 - val_recall: 0.9947 - lr: 1.0000e-04
# Epoch 28/200
# 143/143 [==============================] - 16s 115ms/step - loss: 0.6482 - sparse_categorical_accuracy: 0.9575 - precision: 0.7842 - recall: 1.0254 - val_loss: 0.7914 - val_sparse_categorical_accuracy: 0.9133 - val_precision: 0.8034 - val_recall: 0.9985 - lr: 1.0000e-04
# Epoch 29/200
# 143/143 [==============================] - ETA: 0s - loss: 0.6300 - sparse_categorical_accuracy: 0.9619 - precision: 0.7845 - recall: 1.0248
# Epoch 29: ReduceLROnPlateau reducing learning rate to 1.0000000474974514e-05.
# 143/143 [==============================] - 16s 115ms/step - loss: 0.6300 - sparse_categorical_accuracy: 0.9619 - precision: 0.7845 - recall: 1.0248 - val_loss: 0.6970 - val_sparse_categorical_accuracy: 0.9422 - val_precision: 0.8062 - val_recall: 1.0024 - lr: 1.0000e-04
# Epoch 30/200
# 143/143 [==============================] - 16s 115ms/step - loss: 0.6083 - sparse_categorical_accuracy: 0.9711 - precision: 0.7823 - recall: 1.0230 - val_loss: 0.6907 - val_sparse_categorical_accuracy: 0.9299 - val_precision: 0.8088 - val_recall: 1.0093 - lr: 1.0000e-05
# Epoch 31/200
# 143/143 [==============================] - 16s 115ms/step - loss: 0.5620 - sparse_categorical_accuracy: 0.9781 - precision: 0.7786 - recall: 1.0177 - val_loss: 0.6476 - val_sparse_categorical_accuracy: 0.9343 - val_precision: 0.8042 - val_recall: 1.0038 - lr: 1.0000e-05
# Epoch 32/200
# 143/143 [==============================] - 17s 116ms/step - loss: 0.5319 - sparse_categorical_accuracy: 0.9775 - precision: 0.7741 - recall: 1.0144 - val_loss: 0.6218 - val_sparse_categorical_accuracy: 0.9308 - val_precision: 0.8051 - val_recall: 1.0049 - lr: 1.0000e-05
# Epoch 33/200
# 143/143 [==============================] - 17s 115ms/step - loss: 0.4877 - sparse_categorical_accuracy: 0.9853 - precision: 0.7732 - recall: 1.0136 - val_loss: 0.5777 - val_sparse_categorical_accuracy: 0.9466 - val_precision: 0.8052 - val_recall: 1.0093 - lr: 1.0000e-05
# Epoch 34/200
# 143/143 [==============================] - 17s 116ms/step - loss: 0.4662 - sparse_categorical_accuracy: 0.9851 - precision: 0.7697 - recall: 1.0097 - val_loss: 0.5514 - val_sparse_categorical_accuracy: 0.9448 - val_precision: 0.8048 - val_recall: 1.0073 - lr: 1.0000e-05
# Epoch 35/200
# 143/143 [==============================] - 17s 116ms/step - loss: 0.4432 - sparse_categorical_accuracy: 0.9829 - precision: 0.7730 - recall: 1.0126 - val_loss: 0.5363 - val_sparse_categorical_accuracy: 0.9431 - val_precision: 0.8035 - val_recall: 1.0055 - lr: 1.0000e-05
# Epoch 36/200
# 143/143 [==============================] - 17s 115ms/step - loss: 0.4125 - sparse_categorical_accuracy: 0.9886 - precision: 0.7704 - recall: 1.0103 - val_loss: 0.5038 - val_sparse_categorical_accuracy: 0.9483 - val_precision: 0.8042 - val_recall: 1.0036 - lr: 1.0000e-05
# Epoch 37/200
# 143/143 [==============================] - 17s 116ms/step - loss: 0.3896 - sparse_categorical_accuracy: 0.9888 - precision: 0.7724 - recall: 1.0128 - val_loss: 0.4970 - val_sparse_categorical_accuracy: 0.9448 - val_precision: 0.8016 - val_recall: 1.0014 - lr: 1.0000e-05
# Epoch 38/200
# 143/143 [==============================] - 17s 116ms/step - loss: 0.3700 - sparse_categorical_accuracy: 0.9891 - precision: 0.7692 - recall: 1.0084 - val_loss: 0.4739 - val_sparse_categorical_accuracy: 0.9466 - val_precision: 0.8003 - val_recall: 1.0023 - lr: 1.0000e-05
# Epoch 39/200
# 143/143 [==============================] - 17s 116ms/step - loss: 0.3539 - sparse_categorical_accuracy: 0.9886 - precision: 0.7687 - recall: 1.0078 - val_loss: 0.4663 - val_sparse_categorical_accuracy: 0.9457 - val_precision: 0.8013 - val_recall: 1.0010 - lr: 1.0000e-05
# Epoch 40/200
# 143/143 [==============================] - 17s 115ms/step - loss: 0.3354 - sparse_categorical_accuracy: 0.9906 - precision: 0.7670 - recall: 1.0064 - val_loss: 0.4522 - val_sparse_categorical_accuracy: 0.9431 - val_precision: 0.8020 - val_recall: 1.0044 - lr: 1.0000e-05
# Epoch 41/200
# 143/143 [==============================] - 17s 115ms/step - loss: 0.3232 - sparse_categorical_accuracy: 0.9908 - precision: 0.7672 - recall: 1.0066 - val_loss: 0.4218 - val_sparse_categorical_accuracy: 0.9466 - val_precision: 0.8000 - val_recall: 1.0011 - lr: 1.0000e-05
# Epoch 42/200
# 143/143 [==============================] - 16s 115ms/step - loss: 0.3052 - sparse_categorical_accuracy: 0.9921 - precision: 0.7648 - recall: 1.0040 - val_loss: 0.4181 - val_sparse_categorical_accuracy: 0.9483 - val_precision: 0.8010 - val_recall: 1.0022 - lr: 1.0000e-05
# Epoch 43/200
# 143/143 [==============================] - 17s 116ms/step - loss: 0.2968 - sparse_categorical_accuracy: 0.9928 - precision: 0.7670 - recall: 1.0062 - val_loss: 0.4051 - val_sparse_categorical_accuracy: 0.9475 - val_precision: 0.8006 - val_recall: 1.0046 - lr: 1.0000e-05
# Epoch 44/200
# 143/143 [==============================] - 16s 115ms/step - loss: 0.2826 - sparse_categorical_accuracy: 0.9908 - precision: 0.7677 - recall: 1.0070 - val_loss: 0.4043 - val_sparse_categorical_accuracy: 0.9518 - val_precision: 0.7991 - val_recall: 0.9991 - lr: 1.0000e-05
# Epoch 45/200
# 143/143 [==============================] - 17s 116ms/step - loss: 0.2711 - sparse_categorical_accuracy: 0.9930 - precision: 0.7665 - recall: 1.0063 - val_loss: 0.3858 - val_sparse_categorical_accuracy: 0.9527 - val_precision: 0.8021 - val_recall: 1.0057 - lr: 1.0000e-05
# Epoch 46/200
# 143/143 [==============================] - 17s 116ms/step - loss: 0.2680 - sparse_categorical_accuracy: 0.9906 - precision: 0.7669 - recall: 1.0063 - val_loss: 0.3618 - val_sparse_categorical_accuracy: 0.9536 - val_precision: 0.7994 - val_recall: 1.0014 - lr: 1.0000e-05
# Epoch 47/200
# 143/143 [==============================] - 16s 115ms/step - loss: 0.2532 - sparse_categorical_accuracy: 0.9939 - precision: 0.7660 - recall: 1.0055 - val_loss: 0.3755 - val_sparse_categorical_accuracy: 0.9448 - val_precision: 0.7996 - val_recall: 0.9992 - lr: 1.0000e-05
# Epoch 48/200
# 143/143 [==============================] - 17s 116ms/step - loss: 0.2419 - sparse_categorical_accuracy: 0.9945 - precision: 0.7651 - recall: 1.0048 - val_loss: 0.3483 - val_sparse_categorical_accuracy: 0.9518 - val_precision: 0.8015 - val_recall: 1.0055 - lr: 1.0000e-05
# Epoch 49/200
# 143/143 [==============================] - 17s 116ms/step - loss: 0.2350 - sparse_categorical_accuracy: 0.9945 - precision: 0.7659 - recall: 1.0059 - val_loss: 0.3394 - val_sparse_categorical_accuracy: 0.9545 - val_precision: 0.7987 - val_recall: 1.0014 - lr: 1.0000e-05
# Epoch 50/200
# 143/143 [==============================] - 16s 115ms/step - loss: 0.2247 - sparse_categorical_accuracy: 0.9950 - precision: 0.7650 - recall: 1.0046 - val_loss: 0.3394 - val_sparse_categorical_accuracy: 0.9553 - val_precision: 0.7988 - val_recall: 1.0023 - lr: 1.0000e-05
# Epoch 51/200
# 143/143 [==============================] - 17s 116ms/step - loss: 0.2209 - sparse_categorical_accuracy: 0.9954 - precision: 0.7665 - recall: 1.0062 - val_loss: 0.3379 - val_sparse_categorical_accuracy: 0.9518 - val_precision: 0.7986 - val_recall: 1.0013 - lr: 1.0000e-05
# Epoch 52/200
# 143/143 [==============================] - 16s 115ms/step - loss: 0.2102 - sparse_categorical_accuracy: 0.9965 - precision: 0.7639 - recall: 1.0030 - val_loss: 0.3382 - val_sparse_categorical_accuracy: 0.9536 - val_precision: 0.7993 - val_recall: 1.0011 - lr: 1.0000e-05
# Epoch 53/200
# 143/143 [==============================] - 16s 115ms/step - loss: 0.2097 - sparse_categorical_accuracy: 0.9952 - precision: 0.7650 - recall: 1.0044 - val_loss: 0.3416 - val_sparse_categorical_accuracy: 0.9475 - val_precision: 0.7982 - val_recall: 0.9991 - lr: 1.0000e-05
# Epoch 54/200
# 143/143 [==============================] - 17s 116ms/step - loss: 0.2013 - sparse_categorical_accuracy: 0.9950 - precision: 0.7646 - recall: 1.0042 - val_loss: 0.3216 - val_sparse_categorical_accuracy: 0.9518 - val_precision: 0.7997 - val_recall: 1.0034 - lr: 1.0000e-05
# Epoch 55/200
# 143/143 [==============================] - 17s 116ms/step - loss: 0.1943 - sparse_categorical_accuracy: 0.9950 - precision: 0.7658 - recall: 1.0051 - val_loss: 0.3030 - val_sparse_categorical_accuracy: 0.9562 - val_precision: 0.7997 - val_recall: 1.0033 - lr: 1.0000e-05
# Epoch 56/200
# 143/143 [==============================] - 16s 115ms/step - loss: 0.1917 - sparse_categorical_accuracy: 0.9956 - precision: 0.7659 - recall: 1.0053 - val_loss: 0.3077 - val_sparse_categorical_accuracy: 0.9562 - val_precision: 0.7991 - val_recall: 1.0002 - lr: 1.0000e-05
# Epoch 57/200
# 143/143 [==============================] - 16s 115ms/step - loss: 0.1904 - sparse_categorical_accuracy: 0.9937 - precision: 0.7660 - recall: 1.0047 - val_loss: 0.3130 - val_sparse_categorical_accuracy: 0.9518 - val_precision: 0.8004 - val_recall: 1.0035 - lr: 1.0000e-05
# Epoch 58/200
# 143/143 [==============================] - 16s 115ms/step - loss: 0.1857 - sparse_categorical_accuracy: 0.9950 - precision: 0.7642 - recall: 1.0031 - val_loss: 0.3084 - val_sparse_categorical_accuracy: 0.9527 - val_precision: 0.7986 - val_recall: 1.0009 - lr: 1.0000e-05
# Epoch 59/200
# 143/143 [==============================] - 17s 116ms/step - loss: 0.1810 - sparse_categorical_accuracy: 0.9950 - precision: 0.7665 - recall: 1.0064 - val_loss: 0.2833 - val_sparse_categorical_accuracy: 0.9623 - val_precision: 0.7980 - val_recall: 1.0012 - lr: 1.0000e-05
# Epoch 60/200
# 143/143 [==============================] - 16s 115ms/step - loss: 0.1820 - sparse_categorical_accuracy: 0.9937 - precision: 0.7665 - recall: 1.0064 - val_loss: 0.3060 - val_sparse_categorical_accuracy: 0.9545 - val_precision: 0.7985 - val_recall: 1.0000 - lr: 1.0000e-05
# Epoch 61/200
# 143/143 [==============================] - 16s 115ms/step - loss: 0.1761 - sparse_categorical_accuracy: 0.9937 - precision: 0.7649 - recall: 1.0037 - val_loss: 0.3108 - val_sparse_categorical_accuracy: 0.9553 - val_precision: 0.7976 - val_recall: 0.9979 - lr: 1.0000e-05
# Epoch 62/200
# 143/143 [==============================] - 16s 115ms/step - loss: 0.1701 - sparse_categorical_accuracy: 0.9956 - precision: 0.7651 - recall: 1.0048 - val_loss: 0.2927 - val_sparse_categorical_accuracy: 0.9545 - val_precision: 0.7993 - val_recall: 1.0012 - lr: 1.0000e-05
# Epoch 63/200
# 143/143 [==============================] - 16s 115ms/step - loss: 0.1656 - sparse_categorical_accuracy: 0.9961 - precision: 0.7656 - recall: 1.0051 - val_loss: 0.2940 - val_sparse_categorical_accuracy: 0.9571 - val_precision: 0.7999 - val_recall: 1.0000 - lr: 1.0000e-05
# Epoch 64/200
# 143/143 [==============================] - ETA: 0s - loss: 0.1629 - sparse_categorical_accuracy: 0.9965 - precision: 0.7651 - recall: 1.0049
# Epoch 64: ReduceLROnPlateau reducing learning rate to 1.0000000656873453e-06.
# 143/143 [==============================] - 16s 115ms/step - loss: 0.1629 - sparse_categorical_accuracy: 0.9965 - precision: 0.7651 - recall: 1.0049 - val_loss: 0.2913 - val_sparse_categorical_accuracy: 0.9571 - val_precision: 0.7978 - val_recall: 1.0002 - lr: 1.0000e-05
# Epoch 65/200
# 143/143 [==============================] - 16s 115ms/step - loss: 0.1594 - sparse_categorical_accuracy: 0.9969 - precision: 0.7635 - recall: 1.0027 - val_loss: 0.2950 - val_sparse_categorical_accuracy: 0.9545 - val_precision: 0.7978 - val_recall: 1.0002 - lr: 1.0000e-06
# Epoch 66/200
# 143/143 [==============================] - 16s 115ms/step - loss: 0.1566 - sparse_categorical_accuracy: 0.9974 - precision: 0.7648 - recall: 1.0037 - val_loss: 0.2856 - val_sparse_categorical_accuracy: 0.9571 - val_precision: 0.7984 - val_recall: 0.9990 - lr: 1.0000e-06
# Epoch 67/200
# 143/143 [==============================] - 16s 115ms/step - loss: 0.1571 - sparse_categorical_accuracy: 0.9972 - precision: 0.7646 - recall: 1.0036 - val_loss: 0.2927 - val_sparse_categorical_accuracy: 0.9536 - val_precision: 0.7977 - val_recall: 0.9989 - lr: 1.0000e-06
# Epoch 68/200
# 143/143 [==============================] - 16s 115ms/step - loss: 0.1577 - sparse_categorical_accuracy: 0.9967 - precision: 0.7635 - recall: 1.0026 - val_loss: 0.2903 - val_sparse_categorical_accuracy: 0.9536 - val_precision: 0.7985 - val_recall: 1.0000 - lr: 1.0000e-06
# Epoch 69/200
# 143/143 [==============================] - ETA: 0s - loss: 0.1553 - sparse_categorical_accuracy: 0.9967 - precision: 0.7639 - recall: 1.0031
# Epoch 69: ReduceLROnPlateau reducing learning rate to 1.0000001111620805e-07.
# 143/143 [==============================] - 17s 116ms/step - loss: 0.1553 - sparse_categorical_accuracy: 0.9967 - precision: 0.7639 - recall: 1.0031 - val_loss: 0.2873 - val_sparse_categorical_accuracy: 0.9562 - val_precision: 0.7978 - val_recall: 1.0000 - lr: 1.0000e-06

# %% [markdown]
# ### Metrics Visualization
#
# Next, we plot the training and validation metrics to monitor the model's performance during training. The following metrics are visualized in separate subplots:

# %%
plt.figure(figsize=(10, 7))

# Accuracy
plt.subplot(2, 2, 1)
plt.plot(range(1, len(history.history['sparse_categorical_accuracy']) + 1), history.history['sparse_categorical_accuracy'], label='Train Accuracy')
plt.plot(range(1, len(history.history['val_sparse_categorical_accuracy']) + 1), history.history['val_sparse_categorical_accuracy'], label='Validation Accuracy')
plt.xlabel('Epoch')
plt.ylabel('Accuracy')
plt.title('Training and Validation Accuracy')
plt.legend()

# Loss
plt.subplot(2, 2, 2)
plt.plot(range(1, len(history.history['loss']) + 1), history.history['loss'], label='Train Loss')
plt.plot(range(1, len(history.history['val_loss']) + 1), history.history['val_loss'], label='Validation Loss')
plt.xlabel('Epoch')
plt.ylabel('Loss')
plt.title('Training and Validation Loss')
plt.legend()

# Precision
plt.subplot(2, 2, 3)
plt.plot(range(1, len(history.history['precision']) + 1), history.history['precision'], label='Train Precision')
plt.plot(range(1, len(history.history['val_precision']) + 1), history.history['val_precision'], label='Validation Precision')
plt.xlabel('Epoch')
plt.ylabel('Precision')
plt.title('Training and Validation Precision')
plt.legend()

# Recall
plt.subplot(2, 2, 4)
plt.plot(range(1, len(history.history['recall']) + 1), history.history['recall'], label='Train Recall')
plt.plot(range(1, len(history.history['val_recall']) + 1), history.history['val_recall'], label='Validation Recall')
plt.xlabel('Epoch')
plt.ylabel('Recall')
plt.title('Training and Validation Recall')
plt.legend()

plt.tight_layout()
plt.show()

# %% [markdown]
# ## Image Prediction using the Trained Model
#
# In this section, we implement a function called `predict_image` to predict the tumor class of a single image using the trained brain tumor classification model.
#
# ### Function: `predict_image`

# %%
def predict_image(example):
    img = tf.keras.utils.load_img(example, target_size=(IMG_HEIGHT, IMG_WIDTH))
    img_array = tf.keras.utils.img_to_array(img)
    img_array = tf.expand_dims(img_array, 0) # Create a batch

    predictions = model.predict(img_array)
    score = tf.nn.softmax(predictions[0])

    print(
        "This image most likely belongs to {} with a {:.2f} percent confidence."
        .format(class_names[np.argmax(score)], 100 * np.max(score))
    )

# %% [markdown]
# ### How to Use the Function
#
# To make predictions on a single image, you can call the `predict_image` function and pass the image's file path as an argument. The function will load and preprocess the image, then use the trained model to predict the tumor class and its associated confidence score.

# %%
example = '/kaggle/input/brain-tumor-mri-dataset/Training/glioma/Tr-gl_0584.jpg'
predict_image(example)
# Out:
# 1/1 [==============================] - 0s 324ms/step
# This image most likely belongs to glioma with a 47.43 percent confidence.

# %% [markdown]
# The output will display the predicted tumor class and the associated confidence score for the provided image.

# %% [markdown]
# ## Model Evaluation on Test Dataset
#
# In this section, we evaluate the trained brain tumor classification model on the test dataset to assess its performance on unseen data.
#
# ### Test Dataset
#
# We use the `tf.keras.utils.image_dataset_from_directory` function to create the test dataset (`test_ds`) from the test data directory (`test_data_dir`). The test dataset contains 1311 files belonging to 4 classes.

# %%
test_ds = tf.keras.utils.image_dataset_from_directory(
  test_data_dir,
  seed=123,
  image_size=(IMG_HEIGHT, IMG_WIDTH),
  batch_size=BATCH_SIZE)
# Out:
# Found 1311 files belonging to 4 classes.

# %% [markdown]
# ### Model Evaluation
#
# Next, we evaluate the model on the test dataset using the `model.evaluate` method. The evaluation provides the loss, sparse categorical accuracy, precision, and recall metrics for the model's performance on the test data.

# %%
model.evaluate(test_ds)
# Out:
# 41/41 [==============================] - 3s 62ms/step - loss: 0.2745 - sparse_categorical_accuracy: 0.9687 - precision: 0.7734 - recall: 1.0031
# [0.27453169226646423,
#  0.9687261581420898,
#  0.7733821868896484,
#  1.0030964612960815]

# %% [markdown]
# The output of the evaluation will be a list of metrics, including:
#
# *   Loss: The evaluation loss, which represents the model's performance error on the test data.
# *   Sparse Categorical Accuracy: The evaluation accuracy, which shows the proportion of correctly predicted samples among all test samples.
# *   Precision: The precision metric, indicating the model's ability to correctly identify positive samples (tumor presence) among all predicted positive samples.
# *   Recall: The recall metric, measuring the model's ability to correctly identify positive samples among all actual positive samples.
#
# ### Evaluation Results
#
# After evaluating the model, we obtained the following results:
#
# * Loss: 0.2745
# * Sparse Categorical Accuracy: 0.9687
# * Precision: 0.7734
# * Recall: 1.00

# %% [markdown]
# ## Saving Our Model

# %%
model.save('./models', save_format='tf')

# %% [markdown]
# ## Conclusion
#
# In this notebook, we successfully built a brain tumor classification model using deep learning techniques. We trained the model on a dataset of brain MRI images, which includes four classes: 'glioma', 'meningioma', 'notumor', and 'pituitary' tumors. The model was designed to predict the presence of a tumor and classify it into the appropriate tumor type.
#
# ### Model Architecture and Training
#
# The model architecture consists of convolutional layers, pooling layers, batch normalization, dropout, and dense layers. To handle class imbalance in the dataset, we used custom class weights during training. Additionally, we implemented data augmentation to improve model generalization.
#
# The model was trained on a training dataset, and its performance was monitored on a validation dataset. We utilized several evaluation metrics, such as accuracy, loss, precision, and recall, to assess the model's performance during training. The early stopping and learning rate scheduling callbacks were employed to prevent overfitting and optimize the training process.
#
# ### Model Evaluation
#
# After training, we evaluated the model on an unseen test dataset. The evaluation results showed promising performance with high accuracy and reasonable precision and recall values.
#
# ### Image Prediction
#
# We also implemented a function to make predictions on individual brain MRI images using the trained model. The function loads and preprocesses the image and predicts the tumor class along with a confidence score.
#
# ### Next Steps
#
# Although the model demonstrated good performance, there are still opportunities for further improvements. You may consider experimenting with different model architectures, adjusting hyperparameters, or exploring more advanced techniques to enhance the model's accuracy and generalization.
#
# ### Acknowledgments
#
# We would like to acknowledge the dataset providers and the community for making this research and project possible.
#
# Thank you for joining us on this journey of building a brain tumor classification model! If you have any questions or feedback, please feel free to reach out.
#
# Happy learning and coding!
